# %% [markdown]
# ### 제목
# ** test **
# - 데이터수집
# - 데이터 전처리
#
# 1. 데이터불러오기
# 1. 모델학습
# 1. 결과평가
#
# `print("hello python")`
#
# ```python
# print("hello python")
# df=pd.read_me("test.csv")
# ```
#
#
# |컬럼|설명|
# |----|-----|
# |x   |압력  |
#
#
# 구글 링크: [구글](http://google.com)
#
#
# ![이미지](이미지경로)
#
# ---
#
# - [] 데이터로드(체크박스)

# %%
print("test")
# Out:
# test
